# %% [markdown]
# # Webscrap project: extracción de ofertas laborales de empleospúblico.cl en base a palabras clave

# %% [markdown]
# ## Read Me
# Este código utiliza técnicas de web scrapping y procesamiento de texto (utilizando regular expressions) para acceder a cada una de las más de 500 ofertas de empleos en el sitio web "empleospublicos.cl". El código identifica las ofertas laborales, extrae el texto descriptivo del perfil del cargo y de las especificaciones de la oferta laboral y finalmente genera una base de datos con aquellas ofertas laborales que cumplen con contener ciertas palabras clave que sugieran que es un cargo adecuado para mi perfil profesional.
#
# Este código es 100\% de mi autoría como también la idea original.

# %% [markdown]
# ## I) Extraer código HTML
#
# El sitio web empleospublicos.cl contiene código dinámico, por lo que utilizamos Selenium para extraer manualmente el código.

# %%
import os

chromedriver_directorio = "C:\\Users\\rafae\\Downloads\\chromedriver-win64"
data_directorio = "C:\\Users\\rafae\\Documents\\github\\proyectos\\webscrap_ep_1\\data_extraida"

os.chdir(data_directorio)
os.getcwd()
# Out:
# 'C:\\Users\\rafae\\Documents\\github\\proyectos\\webscrap_ep_1\\data_extraida'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time

#1) Utilizamos el paquete Selenium para ingresar a la pagina web y extraer el código html. Utilizamos Selenium puesto que el código de la página es dinámico.
s = Service(f"{chromedriver_directorio}\\chromedriver.exe") # Recordar descargar el driver compatible con la versión de google chrome
driver = webdriver.Chrome(service=s)

# Este código extrae información del sitio web empleospúblicos.cl
driver.get("https://www.empleospublicos.cl/") 

time.sleep(1) # agregamos tiempo de descanso al código para esperar que la página cargue correctamente
html_content = driver.page_source # extraemos código HTML
print("número de carácteres del código html: ",len(html_content))

driver.quit() # Cerramos la ventana de google chrome luego de extraer el código



#2) Utilizamos Beautifulsoup para poder trabajar más fácilmente con el código HTML
soup = BeautifulSoup(html_content, "lxml")

# A continuación generaremos una lista llamada items_href con todos los links de ofertas laborales en el sitio web
items = soup.find_all('div', class_='item') 
print("número de ofertas en empleospúblicos.cl:",len(items))
h3_href= items[1].find('h3').find('a', {'target': '_blank'}, href=True).get("href")
items_href=[]
for item in items:
    h3_href= item.find('h3').find('a', {'target': '_blank'}, href=True).get("href")
    items_href.append(h3_href)
# Out:
# número de carácteres del código html:  1887761
# número de ofertas en empleospúblicos.cl: 526

# %% [markdown]
# ## II) Iterar a través de las ofertas laborales
#
# Luego de extraer el código html y los links de cada oferta laboral, obtenemos el código html de cada oferta para obtener todo el texto de la oferta laboral e identificar palabras claves.

# %%
import re

# Utilizamos un header que simule el ingreso de un usuario humano, esto sirve para evitar que el sitio web empleospublicos.cl impida acceder 
# a alguna url debido a algún tipo de bloqueo contra automatizaciones de extracción de datos.


#1) definimos parametros de la busqueda
headers = {
    'User-Agent': 'Your-App-Name/0.1',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer your_access_token'
}

#Generamos listas que contendrán la información de cada empleo relevante
economia_link=[]
economia_cargo=[]
economia_fecha=[]
economia_nuevo=[]
palabra_encontrada=[]

# Seleccionamos las palabras claves que el código buscará dentro de cada oferta laboral
words_to_find = ["ingeniería comercial", "ingeniero comercial", "economista", "ingeniero(a) comercial", "ingeniera comercial", "ingeniero/a comercial","ingeniero(a) comercial" ,"civil industrial", "analista", "ciencia de datos", "cientista de datos", "Python", "comercial" ]
#words_to_find = ["stata", "python", "sql"]


# la siguiente porción de código genera un dataframe nuevo en caso de no existir un archivo csv con ofertas laborales anteriores. La idea de esto es poder ir agregando 
# nuevas ofertas a archivos csv creados anteriormente con ofertas laborales antiguas.
try:
    df = pd.read_csv('data.csv')  
except (FileNotFoundError, NameError):
    # Si el archivo data.csv no existe, creamos nuevo dataframe
    data = {
    "Nombre Oferta": economia_cargo,
    "Plazo hasta": economia_fecha,
    "Link": economia_link,
    "Nuevo": economia_nuevo,
    "Palabra Clave": palabra_encontrada
}
    df = pd.DataFrame(data)  
link_set = set(df['Link'])



# creamos clase en caso de tener que lidiar con la ausencia de elementos html específicos, esto ocurre pues a medida que pasa
# el tiempo las clases e "id"s del código html van cambiando para algunas ofertas.
class ElementWithAttribute:
  def __init__(self, value):
    self.string = value



# A continuación utilizamos un loop que trabaja para identificar las palabras claves en cada foerta laboral
# por lo tanto el loop itera a través de la lista items_href que contiene cada link asociado a una oferta laboral
count=0
for item in items_href:
    count=count+1
    print("link número",count)
    
    # 1) conectarnos al link para extraer el código html
    try: 
        while True:     
            r = requests.get(item, headers=headers)
            if r.status_code == 200:
                break  # Exit the loop after successful response
    except:
        # En caso de no poder acceder al link, creamos una fila en el dataframe ( utilizando listas) que indique "error2"
        economia_link.append("error2")
        economia_cargo.append("error2")
        economia_fecha.append("error2")
        economia_nuevo.append("error2")
        palabra_encontrada.append("error2")
        continue
        
        
        
    # 2) trabajamos código html con beautiful soup        
    soup = BeautifulSoup(r.text, "lxml")
    soup_text=soup.get_text(strip=True).lower()
    
    # Ahora utilizamos expresiones regulares para ver si en el perfil del cargo están presentes las palabras claves definidas en la lista
    # "words_to_find" definida anteriormente
    for word in words_to_find:    
        if word in soup_text: 
            # Si la palabra clave se encuentra en el link, extraer la siguiente información y agregarla como fila al dataframe (mediante listas)
            # 2.1) agregamos link
            economia_link.append(item)
            # 2.2) agregamos nombre de cargo, el cual siempre sigue la misma id en todas las ofertas
            element = soup.find("span", id="lblAvisoTrabajo")
            if element!=None:
                cargo = element.string
            # a veces hay ofertas donde el cargo tiene otra id asociada en el código html:
            else:
                element = soup.find("span", id="lblTitulo")
                if element!=None:
                    element = element.find("strong")
                else:
                    element = ElementWithAttribute("error")
                if element==None:
                    element = ElementWithAttribute("error")
                cargo = element.string
            economia_cargo.append(cargo)
            print(cargo)
            
            # 2.3) agregamos fecha de cierre de postulación y la palabra clave encontrada
            element = soup.find("span", id="lblCalendarizacion")
            if element!=None:
                element2 = element.find_all("tr")
                element3 = element2[2].find_all("td")
                element3=element3[1]
                fechapostular = element3.string
                fechapostular = fechapostular.split("-")[1]
                economia_fecha.append(fechapostular)
                palabra_encontrada.append(word)
            else:
                element = soup.find("table", id="lblCalendarizacion")
                if element!=None:
                    element2 = element.find_all("tr")
                    element3 = element2[2].find_all("td")[-1]
                    fechapostular = element3.string
                    fechapostular = fechapostular.split("-")[1]
                    economia_fecha.append(fechapostular)
                    palabra_encontrada.append(word)
                else:
                    element2 = ElementWithAttribute("error")
                    element3 = ElementWithAttribute("error")
                    fechapostular = "error"
                    economia_fecha.append(fechapostular)
                    palabra_encontrada.append(fechapostular)
                    
            # Finalmente especificamos si la oferta encontrada estaba presente anteriormente en el dataframe o si es una oferta nueva  
            if item in link_set:
                economia_nuevo.append("-")
            else:
                economia_nuevo.append("nuevo")
            print("Oferta para economista en:", item)
            print(fechapostular)
            break # pasar a la siguiente iteración en caso de encontrar palabra clave
# Out:
# link número 1
# link número 2
# link número 3
# link número 4
# link número 5
# Encargada (o) de Sección Gestión de Personas - Servicio de Biodiversidad y Áreas Protegidas - 121744
# Oferta para economista en: https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=121744&c=0&j=0&tipo=convpostularavisoTrabajo
# 13/12/2024
# link número 6
# link número 7
# link número 8
# link número 9
# link número 10
# link número 11
# link número 12
# link número 13
# link número 14
# link número 15
# link número 16
# link número 17
# link número 18
# link número 19
# link número 20
# link número 21
# link número 22
# link número 23
# link número 24
# link número 25
# link número 26
# link número 27
# link número 28
# El Servicio Local de Educación Pública de Valparaíso busca Analista de Gestión de Proyectos e Infraestructura 13° EUS
# Oferta para economista en: https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=115445&c=0&j=0&tipo=convpostularavisoTrabajo
# 12/12/2024
# link número 29
# link número 30
# Analista Económico - Estadístico - Dirección Regional de Los Ríos
# Oferta para economista en: https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=120841&c=0&j=0&tipo=convpostularavisoTrabajo
# 13/12/2024
# link número 31
# link número 32
# link número 33
# link número 34
# link número 35
# link número 36
# link número 37
# link número 38
# link número 39
# link número 40
# link número 41
# link número 42
# link número 43
# link número 44
# link número 45
# Encargado(a) de Planificación y Control de Gestión, Región de Atacama
# Oferta para economista en: https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122369&c=0&j=0&tipo=convpostularavisoTrabajo
# 19/12/2024
# link número 46
# Analista Geoespacial – Unidad de Infraestructura de Ñuble
# Oferta para economista en: https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=120842&c=0&j=0&tipo=convpostularavisoTrabajo
# 13/12/2024
# link número 47
# Técnico en Enfermería, 4to Turno para Unidad Central de Esterilización - Grado 19 E.U.S.
# Oferta para economista en: https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122336&c=0&j=0&tipo=convpostularavisoTrabajo
# 18/12/2024
# link número 48
# link número 49
# link número 50
# Analista Unidad de Planificación y Gestión de la Oferta Regional - Dirección Regional - Región de Atacama - PRS 05.12.2024
# Oferta para economista en: https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=121510&c=0&j=0&tipo=convpostularavisoTrabajo
# 12/12/2024
# link número 51
# link número 52
# link número 53
# link número 54
# Jefatura Departamento de Gestión de Reportes Gr. 4
# Oferta para economista en: https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122216&c=0&j=0&tipo=convpostularavisoTrabajo
# 17/12/2024
# link número 55
# link número 56
# link número 57
# link número 58
# link número 59
# link número 60
# link número 61
# link número 62
# link número 63
# link número 64
# link número 65
# link número 66
# link número 67
# link número 68
# link número 69
# link número 70
# link número 71
# link número 72
# link número 73
# link número 74
# link número 75
# link número 76
# link número 77
# Subdirector(a) Administrativo(a) Centro de Salud, Centro de Salud y Rehabilitación La Florida, CAPREDENA.-
# Oferta para economista en: https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=121781&c=0&j=0&tipo=convpostularavisoTrabajo
# 13/12/2024
# link número 78
# link número 79
# link número 80
# link número 81
# link número 82
# link número 83
# link número 84
# link número 85
# link número 86
# link número 87
# link número 88
# link número 89
# Código 171: Coordinador(a) Bronco - Infantil – Servicio Consultas y Procedimientos – CR Atención Ambulatoria – Subdirección Médica
# Oferta para economista en: https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122313&c=0&j=0&tipo=convpostularavisoTrabajo
# 18/12/2024
# link número 90
# Gestor(a) Sección Adquisiciones P.M
# Oferta para economista en: https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=
# link número 467
# link número 468
# link número 469
# link número 470
# link número 471
# link número 472
# link número 473
# link número 474
# link número 475
# link número 476
# link número 477
# link número 478
# link número 479
# link número 480
# link número 481
# link número 482
# link número 483
# link número 484
# link número 485
# link número 486
# link número 487
# link número 488
# link número 489
# link número 490
# link número 491
# link número 492
# link número 493
# link número 494
# link número 495
# link número 496
# link número 497
# link número 498
# link número 499
# link número 500
# link número 501
# link número 502
# link número 503
# link número 504
# link número 505
# link número 506
# link número 507
# link número 508
# link número 509
# link número 510
# link número 511
# link número 512
# link número 513
# link número 514
# link número 515
# link número 516
# link número 517
# link número 518
# link número 519
# link número 520
# link número 521
# link número 522
# link número 523
# link número 524
# link número 525
# link número 526

# %% [markdown]
# ## III) Crear dataframe con toda la información extríida

# %%
import pandas as pd
import datetime

# 1) Creamos archivo csv a partir de dataframe creado, con la información extraída de cada oferta laboral donde se encontró la presencia de una palabra clave
data = {
    "Nombre Oferta": economia_cargo,
    "Plazo hasta": economia_fecha,
    "Link": economia_link,
    "Nuevo": economia_nuevo,
    "Palabra Clave":  palabra_encontrada
}

df = pd.DataFrame(data)
df = df.sort_values(by='Palabra Clave')


now = datetime.datetime.now()
date_str = now.strftime("%Y-%m-%d")  
time_str = now.strftime("%H-%M-%S") 
filename = f"data_{date_str}_{time_str}.csv"  

print(filename)

df.to_csv(filename, mode='w', index=False, sep=';')
df
# Out:
# data_2024-12-12_20-09-22.csv
#                                         Nombre Oferta Plazo hasta  \
# 27  Proceso de selección para proveer un cargo de ...  17/12/2024
# 1   El Servicio Local de Educación Pública de Valp...  12/12/2024
# 17  ESTAMENTO PROFESIONAL, CALIDAD JURIDICA CONTRA...  18/12/2024
# 23  Código 170: Médico Especialista – Servicio Neo...  22/01/2025
# 4   Analista Geoespacial – Unidad de Infraestructu...  13/12/2024
# 5   Técnico en Enfermería, 4to Turno para Unidad C...  18/12/2024
# 32  Analista de Desarrollo TI - División de Gestió...  18/12/2024
# 24  Código 168: Coordinador(a) Subunidad Clínica –...  12/12/2024
# 28  Analista Ambiental y Territorial - Unidad de F...  16/12/2024
# 9   Código 171: Coordinador(a) Bronco - Infantil –...  18/12/2024
# 21  Analista Servicio de Bienestar [Estamento Técn...  18/12/2024
# 11  Administrativo Analista de Agendas Clínicas IN...  16/12/2024
# 26  Código 169: Técnico Paramédico – Servicio Medi...  16/12/2024
# 20              Coordinador(a) de Soporte de Sistemas  18/12/2024
# 39  Encargada (o) de Sección de Gestión Procesos y...  13/12/2024
# 25          HOSPITAL DE SAN CARLOS REQUIERE CONTRATAR  13/12/2024
# 30    CARGO ADMINISTRATIVO DEPARTAMENTO FISCALIZACION  12/12/2024
# 35  Técnico de Apoyo del Área de Pesquerías, escal...  12/12/2024
# 38  Director(a) Regional Magallanes y la Antártica...  16/12/2024
# 22  PROFESIONAL DEL ÁREA DE PESQUERÍAS, A CONTRATA...  12/12/2024
# 12            Ejecutivo(a) Comité del Litio y Salares  13/12/2024
# 40                                             error2      error2
# 37                       GESTOR(A)  ADMINISTRATIVO(A)  12/12/2024
# 14  ACADÉMICO CON FUNCIÓN ADMINISTRATIVA DE JEFE D...  16/12/2024
# 13  Analista de Procesos y Riesgos - Subdepto. de ...  16/12/2024
# 7   Jefatura Departamento de Gestión de Reportes G...  17/12/2024
# 19  Auditor o Auditora de Control del Gasto Electoral  17/12/2024
# 18  SLEP Santa Corina busca un(a) Encargado(a) de ...  18/12/2024
# 34  Gestor (a) de Soporte Regional - Dirección Reg...  12/12/2024
# 6   Analista Unidad de Planificación y Gestión de ...  12/12/2024
# 33  Reemplazo Pre-Post Natal: Supervisor (a) Técni...  12/12/2024
# 2   Analista Económico - Estadístico - Dirección R...  13/12/2024
# 36  Encargada(o) de Sección Contabilidad – Servici...  13/12/2024
# 3   Encargado(a) de Planificación y Control de Ges...  19/12/2024
# 31             Director Regional de Aysén - Cód. 2524  22/12/2024
# 8   Subdirector(a) Administrativo(a) Centro de Sal...  13/12/2024
# 10                Gestor(a) Sección Adquisiciones P.M  20/12/2024
# 15                Encargado(a) de Gestión de Personas  12/12/2024
# 16  Proceso de selección para proveer un cargo de ...  18/12/2024
# 29  Profesional del Departamento de Datos, Informa...  13/12/2024
# 0   Encargada (o) de Sección Gestión de Personas -...  13/12/2024
#
#                                                  Link   Nuevo  \
# 27  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 1   https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 17  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 23  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 4   https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 5   https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 32  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 24  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 28  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 9   https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 21  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 11  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 26  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 20  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 39  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 25  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 30  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 35  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 38  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 22  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 12  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 40                                             error2  error2
# 37  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 14  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 13  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 7   https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 19  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 18  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 34  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 6   https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 33  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 2   https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 36  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 3   https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 31  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 8   https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 10  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 15  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 16  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 29  https://www.empleospublicos.cl/pub/convocatori...   nuevo
# 0   https://www.empleospublicos.cl/pub/convocatori...   nuevo
#
#              Palabra Clave
# 27                analista
# 1                 analista
# 17                analista
# 23                analista
# 4                 analista
# 5                 analista
# 32                analista
# 24                analista
# 28                analista
# 9                 analista
# 21                analista
# 11                analista
# 26                analista
# 20        civil industrial
# 39        civil industrial
# 25               comercial
# 30               comercial
# 35               comercial
# 38               comercial
# 22               comercial
# 12               comercial
# 40                  error2
# 37     ingeniero comercial
# 14     ingeniero comercial
# 13     ingeniero comercial
# 7      ingeniero comercial
# 19     ingeniero comercial
# 18  ingeniero(a) comercial
# 34  ingeniero(a) comercial
# 6   ingeniero(a) comercial
# 33  ingeniero(a) comercial
# 2     ingeniería comercial
# 36    ingeniería comercial
# 3     ingeniería comercial
# 31    ingeniería comercial
# 8     ingeniería comercial
# 10    ingeniería comercial
# 15    ingeniería comercial
# 16    ingeniería comercial
# 29    ingeniería comercial
# 0     ingeniería comercial

# %%
for link in df["Link"]:
    print(link)
# Out:
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122137&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=115445&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=120697&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122310&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=120842&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122336&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122157&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=121843&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=120565&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122313&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=118988&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122284&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=121844&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=120987&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=121743&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122178&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122023&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122128&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122247&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122113&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=120986&c=0&j=0&tipo=convpostularavisoTrabajo
# error2
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122258&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122251&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=120840&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122216&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122189&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122588&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=121521&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=121510&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=121522&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=120841&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=121748&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122369&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122571&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=121781&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122364&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122165&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122569&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=122348&c=0&j=0&tipo=convpostularavisoTrabajo
# https://www.empleospublicos.cl/pub/convocatorias/convpostularavisoTrabajo.aspx?i=121744&c=0&j=0&tipo=convpostularavisoTrabajo
